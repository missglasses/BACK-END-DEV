# %%
from matplotlib import pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

#using frmt / format string
plt.plot(xpoints, ypoints, 'o:m')
#lines: - , : , --, -.
#colors: r-red, m-magenta, b-blue, etc.
plt.show()
